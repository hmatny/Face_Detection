# %% [markdown]
# <a href="https://colab.research.google.com/github/hmatny/Face_Detection/blob/master/face_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Face Detection

# %% [markdown]
# # Retrieving Data

# %%
# !wget http://vis-www.cs.umass.edu/fddb/FDDB-folds.tgz && wget http://tamaraberg.com/faceDataset/originalPics.tar.gz
# !ls
# Out:
# --2019-05-01 19:53:27--  http://vis-www.cs.umass.edu/fddb/FDDB-folds.tgz
# Resolving vis-www.cs.umass.edu (vis-www.cs.umass.edu)... 128.119.244.95
# Connecting to vis-www.cs.umass.edu (vis-www.cs.umass.edu)|128.119.244.95|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 160724 (157K) [application/x-gzip]
# Saving to: ‘FDDB-folds.tgz’
#
# FDDB-folds.tgz      100%[===================>] 156.96K  1021KB/s    in 0.2s
#
# 2019-05-01 19:53:27 (1021 KB/s) - ‘FDDB-folds.tgz’ saved [160724/160724]
#
# --2019-05-01 19:53:27--  http://tamaraberg.com/faceDataset/originalPics.tar.gz
# Resolving tamaraberg.com (tamaraberg.com)... 54.221.205.183
# Connecting to tamaraberg.com (tamaraberg.com)|54.221.205.183|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 579061091 (552M) [application/x-gzip]
# Saving to: ‘originalPics.tar.gz’
#
# originalPics.tar.gz 100%[===================>] 552.24M  9.41MB/s    in 50s
#
# ...

# %%
# need to parse through the FDDB folds and divvy up data into training + testing data
# !tar -xvf FDDB-folds.tgz
!
# Out:
# FDDB-folds/
# FDDB-folds/FDDB-fold-01-ellipseList.txt
# FDDB-folds/FDDB-fold-01.txt
# FDDB-folds/FDDB-fold-02-ellipseList.txt
# FDDB-folds/FDDB-fold-02.txt
# FDDB-folds/FDDB-fold-03-ellipseList.txt
# FDDB-folds/FDDB-fold-03.txt
# FDDB-folds/FDDB-fold-04-ellipseList.txt
# FDDB-folds/FDDB-fold-04.txt
# FDDB-folds/FDDB-fold-05-ellipseList.txt
# FDDB-folds/FDDB-fold-05.txt
# FDDB-folds/FDDB-fold-06-ellipseList.txt
# FDDB-folds/FDDB-fold-06.txt
# FDDB-folds/FDDB-fold-07-ellipseList.txt
# FDDB-folds/FDDB-fold-07.txt
# FDDB-folds/FDDB-fold-08-ellipseList.txt
# FDDB-folds/FDDB-fold-08.txt
# FDDB-folds/FDDB-fold-09-ellipseList.txt
# FDDB-folds/FDDB-fold-09.txt
# FDDB-folds/FDDB-fold-10-ellipseList.txt
# FDDB-folds/FDDB-fold-10.txt

# %%
# !cat FDDB-folds/FDDB-fold-01-ellipseList.txt
# ellipse list contains the features found

# !cat FDDB-folds/FDDB-fold-01.txt
#fold-01 contains the pathway to the images inside originalPics/<path>

# TODO:
#need to divvy up into test + training data
#make a list of expected features from ellipseList.txt the test + training data
# Out:
# 2002/08/11/big/img_591
# 2002/08/26/big/img_265
# 2002/07/19/big/img_423
# 2002/08/24/big/img_490
# 2002/08/31/big/img_17676
# 2002/07/31/big/img_228
# 2002/07/24/big/img_402
# 2002/08/04/big/img_769
# 2002/07/19/big/img_581
# 2002/08/13/big/img_723
# 2002/08/12/big/img_821
# 2003/01/17/big/img_610
# 2002/08/13/big/img_1116
# 2002/08/28/big/img_19238
# 2002/08/21/big/img_660
# 2002/08/14/big/img_607
# 2002/08/05/big/img_3708
# 2002/08/19/big/img_511
# 2002/08/07/big/img_1316
# 2002/07/25/big/img_1047
# 2002/07/23/big/img_474
# 2002/07/27/big/img_970
# 2002/09/02/big/img_15752
# 2002/09/01/big/img_16378
# 2002/09/01/big/img_16189
# 2002/08/26/big/img_276
# 2002/07/24/big/img_518
# 2002/08/14/big/img_1027
# 2002/08/24/big/img_733
# 2002/08/15/big/img_249
# 2003/01/15/big/img_1371
# 2002/08/07/big/img_1348
# 2003/01/01/big/img_331
# 2002/08/23/big/img_536
# 2002/07/30/big/img_224
# 2002/08/10/big/img_763
# 2002/08/21/big/img_293
# 2002/08/15/big/img_1211
# 2002/08/15/big/img_1194
# ...
